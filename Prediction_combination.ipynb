# %% [markdown]
# ### Final Prediction Outputs
# The final dataframe is shown below, containing a total of 60,980 rows and 29 columns.
#
# After submitting to Kaggle, the Weighted Root Mean Squared Scaled Error (RMSSE) is 0.80775.
#
# For detailed information on RMSSE, please refer to Kaggle: https://www.kaggle.com/c/m5-forecasting-accuracy/overview/evaluation.

# %%
all_df_final.head()
# Out:
#                               id        F1  ...       F27       F28
# 0  HOBBIES_1_001_CA_1_validation  0.507157  ...  0.618123  0.587058
# 1  HOBBIES_1_002_CA_1_validation  0.169358  ...  0.233939  0.213953
# 2  HOBBIES_1_003_CA_1_validation  0.193616  ...  0.337765  0.291793
# 3  HOBBIES_1_004_CA_1_validation  1.906962  ...  2.614193  3.088436
# 4  HOBBIES_1_005_CA_1_validation  0.739892  ...  1.137252  1.011584
#
# [5 rows x 29 columns]

# %%
all_df_final.shape
# Out:
# (60980, 29)
