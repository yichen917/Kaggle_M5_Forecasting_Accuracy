# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load data

# %%
sells_train = pd.read_csv("sales_train_validation.csv")
sells_train.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# 0       1       3       0       1       1
# 1       1       0       0       0       0
# 2       1       0       1       1       1
# 3       0       1       3       7       2
# 4       1       2       2       2       4
#
# [5 rows x 1919 columns]

# %%
sells_train.shape
# Out:
# (30490, 1919)

# %%
calendar = pd.read_csv("calendar.csv")
calendar.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
calendar.shape
# Out:
# (1969, 14)

# %%
sell_prices = pd.read_csv("sell_prices.csv")
print(sell_prices.shape)
sell_prices.head()
# Out:
# (6841121, 4)
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
sell_prices['wm_yr_wk'].unique()
# Out:
# 282

# %%
sell_prices.set_index(['store_id', 'item_id', 'wm_yr_wk'], inplace=True)
sell_prices.head()
# Out:
#                                  sell_price
# store_id item_id       wm_yr_wk
# CA_1     HOBBIES_1_001 11325           9.58
#                        11326           9.58
#                        11327           8.26
#                        11328           8.26
#                        11329           8.26

# %%
sell_prices.index
# Out:
# MultiIndex([('CA_1', 'HOBBIES_1_001', 11325),
#             ('CA_1', 'HOBBIES_1_001', 11326),
#             ('CA_1', 'HOBBIES_1_001', 11327),
#             ('CA_1', 'HOBBIES_1_001', 11328),
#             ('CA_1', 'HOBBIES_1_001', 11329),
#             ('CA_1', 'HOBBIES_1_001', 11330),
#             ('CA_1', 'HOBBIES_1_001', 11331),
#             ('CA_1', 'HOBBIES_1_001', 11332),
#             ('CA_1', 'HOBBIES_1_001', 11333),
#             ('CA_1', 'HOBBIES_1_001', 11334),
#             ...
#             ('WI_3',   'FOODS_3_827', 11612),
#             ('WI_3',   'FOODS_3_827', 11613),
#             ('WI_3',   'FOODS_3_827', 11614),
#             ('WI_3',   'FOODS_3_827', 11615),
#             ('WI_3',   'FOODS_3_827', 11616),
#             ('WI_3',   'FOODS_3_827', 11617),
#             ('WI_3',   'FOODS_3_827', 11618),
#             ('WI_3',   'FOODS_3_827', 11619),
#             ('WI_3',   'FOODS_3_827', 11620),
#             ('WI_3',   'FOODS_3_827', 11621)],
#            names=['store_id', 'item_id', 'wm_yr_wk'], length=6841121)

# %% [markdown]
# ### Build training dataframe

# %% [markdown]
# We expanded each product to have 1913 rows. This way, we could have historical sales data into daily sales columns, and integrate it with the calendar data.

# %%
id_order = sells_train['id'].tolist()
id_order[:10]
# Out:
# ['HOBBIES_1_001_CA_1_validation',
#  'HOBBIES_1_002_CA_1_validation',
#  'HOBBIES_1_003_CA_1_validation',
#  'HOBBIES_1_004_CA_1_validation',
#  'HOBBIES_1_005_CA_1_validation',
#  'HOBBIES_1_006_CA_1_validation',
#  'HOBBIES_1_007_CA_1_validation',
#  'HOBBIES_1_008_CA_1_validation',
#  'HOBBIES_1_009_CA_1_validation',
#  'HOBBIES_1_010_CA_1_validation']

# %%
day_num = 1913
basic_data = sells_train.iloc[:, :6].copy()
duplicate = [basic_data]*day_num
basic_data = pd.concat(duplicate)
basic_data['id'] = basic_data['id'].astype('category')
basic_data['id'] = basic_data['id'].cat.set_categories(id_order)
basic_data = basic_data.sort_values(by = ['id']).reset_index(drop = True)
basic_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id
# 0       CA
# 1       CA
# 2       CA
# 3       CA
# 4       CA

# %%
day_name = sells_train.columns[6:].tolist()
day_name[:10]
# Out:
# ['d_1', 'd_2', 'd_3', 'd_4', 'd_5', 'd_6', 'd_7', 'd_8', 'd_9', 'd_10']

# %%
sample_num = len(sells_train)
basic_data['d'] = day_name*sample_num
basic_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d
# 0       CA  d_1
# 1       CA  d_2
# 2       CA  d_3
# 3       CA  d_4
# 4       CA  d_5

# %%
sell_amt = np.reshape(sells_train.iloc[:, 6:].values, (day_num*sample_num, 1))
basic_data['num_sold'] = sell_amt
basic_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  num_sold
# 0       CA  d_1         0
# 1       CA  d_2         0
# 2       CA  d_3         0
# 3       CA  d_4         0
# 4       CA  d_5         0

# %%
basic_data.shape
# Out:
# (58327370, 8)

# %%
cal_df = pd.concat([calendar.iloc[:1913]]*sample_num).reset_index(drop=True)
cal_df
# Out:
#                 date  wm_yr_wk    weekday  wday  month  year       d  \
# 0         2011-01-29     11101   Saturday     1      1  2011     d_1
# 1         2011-01-30     11101     Sunday     2      1  2011     d_2
# 2         2011-01-31     11101     Monday     3      1  2011     d_3
# 3         2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4         2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...              ...       ...        ...   ...    ...   ...     ...
# 58327365  2016-04-20     11612  Wednesday     5      4  2016  d_1909
# 58327366  2016-04-21     11612   Thursday     6      4  2016  d_1910
# 58327367  2016-04-22     11612     Friday     7      4  2016  d_1911
# 58327368  2016-04-23     11613   Saturday     1      4  2016  d_1912
# 58327369  2016-04-24     11613     Sunday     2      4  2016  d_1913
#
#          event_name_1 event_type_1 event_name_2 event_type_2  snap_CA  \
# 0                 NaN          NaN          NaN          NaN        0
# 1                 NaN          NaN          NaN          NaN        0
# 2                 NaN          NaN          NaN          NaN        0
# 3                 NaN          NaN          NaN          NaN        1
# 4                 NaN          NaN          NaN          NaN        1
# ...               ...          ...          ...          ...      ...
# 58327365          NaN          NaN          NaN          NaN        0
# 58327366          NaN          NaN          NaN          NaN        0
# 58327367          NaN          NaN          NaN          NaN        0
# 58327368          NaN          NaN          NaN          NaN        0
# 58327369          NaN          NaN          NaN          NaN        0
#
#           snap_TX  snap_WI
# 0               0        0
# 1               0        0
# 2               0        0
# 3               1        0
# 4               0        1
# ...           ...      ...
# 58327365        0        0
# 58327366        0        0
# 58327367        0        0
# 58327368        0        0
# 58327369        0        0
#
# [58327370 rows x 14 columns]

# %%
cal_df.drop(['wday','d'], axis=1, inplace = True)

# %%
cal_df.shape
# Out:
# (58327370, 12)

# %%
train_data = pd.concat([basic_data, cal_df], axis=1)
train_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  num_sold        date  wm_yr_wk    weekday  month  year  \
# 0       CA  d_1         0  2011-01-29     11101   Saturday      1  2011
# 1       CA  d_2         0  2011-01-30     11101     Sunday      1  2011
# 2       CA  d_3         0  2011-01-31     11101     Monday      1  2011
# 3       CA  d_4         0  2011-02-01     11101    Tuesday      2  2011
# 4       CA  d_5         0  2011-02-02     11101  Wednesday      2  2011
#
#   event_name_1 event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  \
# 0          NaN          NaN          NaN          NaN        0        0
# 1          NaN          NaN          NaN          NaN        0        0
# 2          NaN          NaN          NaN          NaN        0        0
# 3          NaN          NaN          NaN          NaN        1        1
# 4          NaN          NaN          NaN          NaN        1        0
#
#    snap_WI
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1

# %%
train_data.shape
# Out:
# (58327370, 20)

# %%
import gc
gc.collect()
# Out:
# 100

# %% [markdown]
# ### Snap and state

# %% [markdown]
# Convert the "snap" column into a single dummy variable column based on the "state".

# %%
state2snap = lambda x: x['snap_CA'] if x['state_id'] == 'CA' else(x['snap_TX'] if x['state_id']=='TX' else x['snap_WI'])

# %%
snap = train_data[['snap_CA', 'snap_TX', 'snap_WI', 'state_id']].apply(state2snap, axis=1)
snap
# Out:
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
#            ..
# 58327365    0
# 58327366    0
# 58327367    0
# 58327368    0
# 58327369    0
# Length: 58327370, dtype: int64

# %%
train_data.drop(['snap_CA', 'snap_TX', 'snap_WI'], inplace = True, axis=1)

# %%
train_data['snap'] = snap

# %%
train_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  num_sold        date  wm_yr_wk    weekday  month  year  \
# 0       CA  d_1         0  2011-01-29     11101   Saturday      1  2011
# 1       CA  d_2         0  2011-01-30     11101     Sunday      1  2011
# 2       CA  d_3         0  2011-01-31     11101     Monday      1  2011
# 3       CA  d_4         0  2011-02-01     11101    Tuesday      2  2011
# 4       CA  d_5         0  2011-02-02     11101  Wednesday      2  2011
#
#   event_name_1 event_type_1 event_name_2 event_type_2  snap
# 0          NaN          NaN          NaN          NaN     0
# 1          NaN          NaN          NaN          NaN     0
# 2          NaN          NaN          NaN          NaN     0
# 3          NaN          NaN          NaN          NaN     1
# 4          NaN          NaN          NaN          NaN     1

# %%
#train_data.to_csv('train.csv',index=False)

# %% [markdown]
# ### Merge

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()
#.progress_apply()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   """Entry point for launching an IPython kernel.
# /Applications/anaconda3/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
train_data = pd.read_csv("train.csv")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  num_sold        date  wm_yr_wk    weekday  month  year  \
# 0       CA  d_1         0  2011-01-29     11101   Saturday      1  2011
# 1       CA  d_2         0  2011-01-30     11101     Sunday      1  2011
# 2       CA  d_3         0  2011-01-31     11101     Monday      1  2011
# 3       CA  d_4         0  2011-02-01     11101    Tuesday      2  2011
# 4       CA  d_5         0  2011-02-02     11101  Wednesday      2  2011
#
#   event_name_1 event_type_1 event_name_2 event_type_2  snap
# 0          NaN          NaN          NaN          NaN     0
# 1          NaN          NaN          NaN          NaN     0
# 2          NaN          NaN          NaN          NaN     0
# 3          NaN          NaN          NaN          NaN     1
# 4          NaN          NaN          NaN          NaN     1

# %%
train_data.shape
# Out:
# (58327370, 18)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58327370 entries, 0 to 58327369
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            object
#  1   item_id       object
#  2   dept_id       object
#  3   cat_id        object
#  4   store_id      object
#  5   state_id      object
#  6   d             object
#  7   num_sold      int64
#  8   date          object
#  9   wm_yr_wk      int64
#  10  weekday       object
#  11  month         int64
#  12  year          int64
#  13  event_name_1  object
#  14  event_type_1  object
#  15  event_name_2  object
#  16  event_type_2  object
#  17  snap          int64
# dtypes: int64(5), object(13)
# memory usage: 7.8+ GB

# %%
sell_prices = pd.read_csv("sell_prices.csv")
print(sell_prices.shape)
sell_prices.head()
# Out:
# (6841121, 4)
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
sell_prices.head(10)
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26
# 5     CA_1  HOBBIES_1_001     11330        8.26
# 6     CA_1  HOBBIES_1_001     11331        8.26
# 7     CA_1  HOBBIES_1_001     11332        8.26
# 8     CA_1  HOBBIES_1_001     11333        8.26
# 9     CA_1  HOBBIES_1_001     11334        8.26

# %%
train_data_withprice=train_data.merge(sell_prices,"left")

# %%
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)

# %%
train_data_withprice.shape
# Out:
# (58327370, 19)

# %%
train_data_withprice.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  num_sold        date  wm_yr_wk    weekday  month  year  \
# 0       CA  d_1         0  2011-01-29     11101   Saturday      1  2011
# 1       CA  d_2         0  2011-01-30     11101     Sunday      1  2011
# 2       CA  d_3         0  2011-01-31     11101     Monday      1  2011
# 3       CA  d_4         0  2011-02-01     11101    Tuesday      2  2011
# 4       CA  d_5         0  2011-02-02     11101  Wednesday      2  2011
#
#   event_name_1 event_type_1 event_name_2 event_type_2  snap  sell_price
# 0          NaN          NaN          NaN          NaN     0         NaN
# 1          NaN          NaN          NaN          NaN     0         NaN
# 2          NaN          NaN          NaN          NaN     0         NaN
# 3          NaN          NaN          NaN          NaN     1         NaN
# 4          NaN          NaN          NaN          NaN     1         NaN

# %%
#train_data_withprice.to_csv('train_with_price_notfill.csv',index=False)

# %% [markdown]
# ## Fill na values for "price"

# %%
full_price=train_data_withprice['sell_price'].fillna(method='bfill')

# %%
train_data_withprice['sell_price']=full_price

# %%
train_data_withprice.head(10)
# Out:
#                                id        item_id    dept_id   cat_id store_id  \
# 0   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 2   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 3   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 4   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 5   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 6   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 7   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 8   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 9   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 10  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 11  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 12  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 13  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 14  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 15  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 16  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 17  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 18  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 19  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 20  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 21  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 22  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 23  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 24  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 25  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 26  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 27  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 28  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 29  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 30  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 31  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 32  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 33  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 34  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 35  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 36  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 37  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 38  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 39  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 40  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 41  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 42  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 43  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 44  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 45  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 46  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 47  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 48  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 49  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 50  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 51  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 52  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 53  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 54  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 55  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 56  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 57  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 58  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 59  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 60  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 61  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 62  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 63  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 64  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 65  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 66  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 67  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 68  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 69  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 70  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 71  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 72  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 73  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 74  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 75  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 76  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 77  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 78  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 79  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 80  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 81  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 82  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 83  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 84  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 85  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 86  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 87  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 88  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 89  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 90  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 91  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 92  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 93  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 94  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 95  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 96  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 97  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 98  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 99  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 93       CA   d_94         0  2011-05-02     11114     Monday      5  2011
# 94       CA   d_95         0  2011-05-03     11114    Tuesday      5  2011
# 95       CA   d_96         0  2011-05-04     11114  Wednesday      5  2011
# 96       CA   d_97         0  2011-05-05     11114   Thursday      5  2011
# 97       CA   d_98         0  2011-05-06     11114     Friday      5  2011
# 98       CA   d_99         0  2011-05-07     11115   Saturday      5  2011
# 99       CA  d_100         0  2011-05-08     11115     Sunday      5  2011
#
#       event_name_1 event_type_1 event_name_2 event_type_2  snap  sell_price
# 0              NaN          NaN          NaN          NaN     0        9.58
# 1              NaN          NaN          NaN          NaN     0        9.58
# 2              NaN          NaN          NaN          NaN     0        9.58
# 3              NaN          NaN          NaN          NaN     1        9.58
# 4              NaN          NaN          NaN          NaN     1        9.58
# 5              NaN          NaN          NaN          NaN     1        9.58
# 6              NaN          NaN          NaN          NaN     1        9.58
# 7              NaN          NaN          NaN          NaN     1        9.58
# 8        SuperBowl     Sporting          NaN          NaN     1        9.58
# 9              NaN          NaN          NaN          NaN     1        9.58
# 10             NaN          NaN          NaN          NaN     1        9.58
# 11             NaN          NaN          NaN          NaN     1        9.58
# 12             NaN          NaN          NaN          NaN     1        9.58
# 13             NaN          NaN          NaN          NaN     0        9.58
# 14             NaN          NaN          NaN          NaN     0        9.58
# 15             NaN          NaN          NaN          NaN     0        9.58
# 16   ValentinesDay     Cultural          NaN          NaN     0        9.58
# 17             NaN          NaN          NaN          NaN     0        9.58
# 18             NaN          NaN          NaN          NaN     0        9.58
# 19             NaN          NaN          NaN          NaN     0        9.58
# 20             NaN          NaN          NaN          NaN     0        9.58
# 21             NaN          NaN          NaN          NaN     0        9.58
# 22             NaN          NaN          NaN          NaN     0        9.58
# 23   PresidentsDay     National          NaN          NaN     0        9.58
# 24             NaN          NaN          NaN          NaN     0        9.58
# 25             NaN          NaN          NaN          NaN     0        9.58
# 26             NaN          NaN          NaN          NaN     0        9.58
# 27             NaN          NaN          NaN          NaN     0        9.58
# 28             NaN          NaN          NaN          NaN     0        9.58
# 29             NaN          NaN          NaN          NaN     0        9.58
# 30             NaN          NaN          NaN          NaN     0        9.58
# 31             NaN          NaN          NaN          NaN     1        9.58
# 32             NaN          NaN          NaN          NaN     1        9.58
# 33             NaN          NaN          NaN          NaN     1        9.58
# 34             NaN          NaN          NaN          NaN     1        9.58
# 35             NaN          NaN          NaN          NaN     1        9.58
# 36             NaN          NaN          NaN          NaN     1        9.58
# 37             NaN          NaN          NaN          NaN     1        9.58
# 38             NaN          NaN          NaN          NaN     1        9.58
# 39       LentStart    Religious          NaN          NaN     1        9.58
# 40             NaN          NaN          NaN          NaN     1        9.58
# 41             NaN          NaN          NaN          NaN     0        9.58
# 42             NaN          NaN          NaN          NaN     0        9.58
# 43             NaN          NaN          NaN          NaN     0        9.58
# 44             NaN          NaN          NaN          NaN     0        9.58
# 45             NaN          NaN          NaN          NaN     0        9.58
# 46       LentWeek2    Religious          NaN          NaN     0        9.58
# 47   StPatricksDay     Cultural          NaN          NaN     0        9.58
# 48             NaN          NaN          NaN          NaN     0        9.58
# 49             NaN          NaN          NaN          NaN     0        9.58
# 50       Purim End    Religious          NaN          NaN     0        9.58
# 51             NaN          NaN          NaN          NaN     0        9.58
# 52             NaN          NaN          NaN          NaN     0        9.58
# 53             NaN          NaN          NaN          NaN     0        9.58
# 54             NaN          NaN          NaN          NaN     0        9.58
# 55             NaN          NaN          NaN          NaN     0        9.58
# 56             NaN          NaN          NaN          NaN     0        9.58
# 57             NaN          NaN          NaN          NaN     0        9.58
# 58             NaN          NaN          NaN          NaN     0        9.58
# 59             NaN          NaN          NaN          NaN     0        9.58
# 60             NaN          NaN          NaN          NaN     0        9.58
# 61             NaN          NaN          NaN          NaN     0        9.58
# 62             NaN          NaN          NaN          NaN     1        9.58
# 63             NaN          NaN          NaN          NaN     1        9.58
# 64             NaN          NaN          NaN          NaN     1        9.58
# 65             NaN          NaN          NaN          NaN     1        9.58
# 66             NaN          NaN          NaN          NaN     1        9.58
# 67             NaN          NaN          NaN          NaN     1        9.58
# 68             NaN          NaN          NaN          NaN     1        9.58
# 69             NaN          NaN          NaN          NaN     1        9.58
# 70             NaN          NaN          NaN          NaN     1        9.58
# 71             NaN          NaN          NaN          NaN     1        9.58
# 72             NaN          NaN          NaN          NaN     0        9.58
# 73             NaN          NaN          NaN          NaN     0        9.58
# 74             NaN          NaN          NaN          NaN     0        9.58
# 75             NaN          NaN          NaN          NaN     0        9.58
# 76             NaN          NaN          NaN          NaN     0        9.58
# 77             NaN          NaN          NaN          NaN     0        9.58
# 78             NaN          NaN          NaN          NaN     0        9.58
# 79             NaN          NaN          NaN          NaN     0        9.58
# 80             NaN          NaN          NaN          NaN     0        9.58
# 81             NaN          NaN          NaN          NaN     0        9.58
# 82             NaN          NaN          NaN          NaN     0        9.58
# 83             NaN          NaN          NaN          NaN     0        9.58
# 84             NaN          NaN          NaN          NaN     0        9.58
# 85  OrthodoxEaster    Religious       Easter     Cultural     0        9.58
# 86             NaN          NaN          NaN          NaN     0        9.58
# 87      Pesach End    Religious          NaN          NaN     0        9.58
# 88             NaN          NaN          NaN          NaN     0        9.58
# 89             NaN          NaN          NaN          NaN     0        9.58
# 90             NaN          NaN          NaN          NaN     0        9.58
# 91             NaN          NaN          NaN          NaN     0        9.58
# 92             NaN          NaN          NaN          NaN     1        9.58
# 93             NaN          NaN          NaN          NaN     1        9.58
# 94             NaN          NaN          NaN          NaN     1        9.58
# 95             NaN          NaN          NaN          NaN     1        9.58
# 96   Cinco De Mayo     Cultural          NaN          NaN     1        9.58
# 97             NaN          NaN          NaN          NaN     1        9.58
# 98             NaN          NaN          NaN          NaN     1        9.58
# 99    Mother's day     Cultural          NaN          NaN     1        9.58

# %%
#train_data_withprice.to_csv('train_with_price.csv',index=False)

# %% [markdown]
# ### The main DataFrame is complete and can now be used in the models.
